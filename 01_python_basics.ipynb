# %%
a = 5

# %%
b = 34

# %%
a+b
# Out:
# 39

# %% [raw]
# same cell = ctrl + enter
# next cell = shift + enter

# %%
name = "harry"
print(name)
# Out:
# harry

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a = "9876"
b = "7865"

# %%
print(a+b)
# Out:
# 98767865

# %%
int(a) + int(b) #type casting
# Out:
# 17741
