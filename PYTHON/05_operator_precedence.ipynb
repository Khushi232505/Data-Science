# %%
result = 10 + 2 *3

# %%
result
# Out:
# 16

# %%
result = (10 + 2) *3

# %%
result
# Out:
# 36

# %%
 result = 2 **3 **2 # 2**(3**2) right to left

# %%
result
# Out:
# 512

# %%
54*3/23+4-2**5
# Out:
# -20.956521739130434

# %% [markdown]
#  # *,/,//, and % have lower precedence than ** but are evaluated left to right
