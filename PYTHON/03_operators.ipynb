# %% [markdown]
# # Arithmetic operators

# %%
a = 10
b = 5

# %%
a+b
# Out:
# 15

# %%
a-b
# Out:
# 5

# %%
a*b
# Out:
# 50

# %%
a/b
# Out:
# 2.0

# %%
a//b
# Out:
# 2

# %%
a%b
# Out:
# 0

# %%
a**b
# Out:
# 100000

# %% [markdown]
# # Comparison operator

# %%
a = 45
b = 4

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %% [markdown]
# # Logical operator

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# # Bitwise operator

# %%
a = 5
b = 3

# %%
a & b
# Out:
# 1

# %%
a | b
# Out:
# 7

# %% [markdown]
# # Assignment operator

# %%
 a = 45

# %%
a += 4
print(a)
# Out:
# 49

# %%
a -= 4
print(a)
# Out:
# 45

# %%
a *= 4
print(a)
# Out:
# 180

# %%
a /= 4
print(a)
# Out:
# 45.0

# %%
a //= 4
print(a)
# Out:
# 11.0

# %%
a %= 4
print(a)
# Out:
# 3.0

# %%
a **= 4
print(a)
# Out:
# 81.0

# %% [markdown]
# # Membership and Identity operator

# %%
list = [1,2,3]

2 in list
# Out:
# True

# %%
1 not in list
# Out:
# False

# %%
a = [1, 2, 3]
b = a

print(a is b)
# Out:
# True

# %%
a = [1, 2, 3]
b = [1, 2, 3]

print(a is not b)
# Out:
# True
